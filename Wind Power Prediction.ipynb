# %% [markdown]
# Wind Power Predication

# %% [markdown]
# Objective

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb

# %%
print("DataFrame head (after previous processing):")
display(df.head())
# Out:
# DataFrame head (after previous processing):
#                            ActivePower  AmbientTemperatue  \
# Date/Time
# 2017-12-31 00:00:00+00:00          NaN                NaN
# 2017-12-31 00:10:00+00:00          NaN                NaN
# 2017-12-31 00:20:00+00:00          NaN                NaN
# 2017-12-31 00:30:00+00:00          NaN                NaN
# 2017-12-31 00:40:00+00:00          NaN                NaN
#
#                            BearingShaftTemperature  Blade1PitchAngle  \
# Date/Time
# 2017-12-31 00:00:00+00:00                      NaN               NaN
# 2017-12-31 00:10:00+00:00                      NaN               NaN
# 2017-12-31 00:20:00+00:00                      NaN               NaN
# 2017-12-31 00:30:00+00:00                      NaN               NaN
# 2017-12-31 00:40:00+00:00                      NaN               NaN
#
#                            Blade2PitchAngle  Blade3PitchAngle  \
# Date/Time
# ...

# %%
display(df.isnull().sum())
# Out:
# ActivePower                     23474
# AmbientTemperatue               24407
# BearingShaftTemperature         55706
# Blade1PitchAngle                76228
# Blade2PitchAngle                76333
# Blade3PitchAngle                76333
# ControlBoxTemperature           56064
# GearboxBearingTemperature       55684
# GearboxOilTemperature           55786
# GeneratorRPM                    55929
# GeneratorWinding1Temperature    55797
# GeneratorWinding2Temperature    55775
# HubTemperature                  55818
# MainBoxTemperature              55717
# NacellePosition                 45946
# ReactivePower                   23476
# RotorRPM                        56097
# TurbineStatus                   55316
# WTG                                 0
# WindDirection                   45946
# WindSpeed                       23629
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets (80/20 ratio, maintaining time series order)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

print("Data split into training and testing sets.")
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Data split into training and testing sets.
# X_train shape: (94579, 2)
# X_test shape: (23645, 2)
# y_train shape: (94579,)
# y_test shape: (23645,)

# %%
# Define features (X) and target (y) from the imputed DataFrame
X = df_imputed[['AmbientTemperatue', 'WindSpeed']]
y = df_imputed['ActivePower']

print("Features (X) head:")
display(X.head())
print("\nTarget (y) head:")
display(y.head())

# Split the data into training and testing sets (80/20 ratio, maintaining time series order)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

print("\nData split into training and testing sets.")
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Features (X) head:
#                            AmbientTemperatue  WindSpeed
# Date/Time
# 2017-12-31 00:00:00+00:00          23.148729   2.279088
# 2017-12-31 00:10:00+00:00          23.148729   2.279088
# 2017-12-31 00:20:00+00:00          23.148729   2.279088
# 2017-12-31 00:30:00+00:00          23.148729   2.279088
# 2017-12-31 00:40:00+00:00          23.148729   2.279088
# Target (y) head:
# Date/Time
# 2017-12-31 00:00:00+00:00   -5.357727
# 2017-12-31 00:10:00+00:00   -5.357727
# 2017-12-31 00:20:00+00:00   -5.357727
# 2017-12-31 00:30:00+00:00   -5.357727
# 2017-12-31 00:40:00+00:00   -5.357727
# Name: ActivePower, dtype: float64
# Data split into training and testing sets.
# X_train shape: (94579, 2)
# X_test shape: (23645, 2)
# y_train shape: (94579,)
# y_test shape: (23645,)

# %%
from sklearn.linear_model import LinearRegression

# Initialize the Linear Regression model
model = LinearRegression()

# Train the model using the training data
model.fit(X_train, y_train)

print("Linear Regression model trained successfully.")
print(f"Model coefficients: {model.coef_}")
print(f"Model intercept: {model.intercept_}")
# Out:
# Linear Regression model trained successfully.
# Model coefficients: [  1.58015579 189.72312873]
# Model intercept: -540.62739757667

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Absolute Error (MAE): 155.35
# R-squared (R2): 0.82
